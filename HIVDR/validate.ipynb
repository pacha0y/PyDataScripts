# %%
pip install sqlalchemy pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: sqlalchemy in c:\users\pachawobisani\appdata\roaming\python\python312\site-packages (2.0.36)
# Requirement already satisfied: pymysql in c:\users\pachawobisani\appdata\roaming\python\python312\site-packages (1.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\pachawobisani\appdata\roaming\python\python312\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\pachawobisani\appdata\roaming\python\python312\site-packages (from sqlalchemy) (3.1.1)

# %%
import pandas as pd
import numpy as np
import mysql.connector
import math

# %%
# Connect to mysql 
conn = mysql.connector.connect(
    host="192.168.3.19",
    user="lighthouse",
    password="letmein",
    database="sample_db"
)

# %%
# Load and clean CSV
def load_and_clean_csv(filepath: str) -> pd.DataFrame:
    df = pd.read_csv(filepath)
    df.columns = (
        df.columns
            .str.strip()
            .str.replace(" ","")
    )
    date_cols = [
        "ApplicationDate",
        "DateEmailReceived",
        "ApprovedDate"
    ]
    for col in date_cols:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col], errors="coerce").dt.date

    bool_map = {
        "Yes": 1, "No": 2, "Unknown": 3,
        "Y": 1, "N": 2, "U": 3,
        True: 1, False: 2
    }
    bool_cols = ["Approved", "SampleSent", "ResultReceived"]
    for col in bool_cols:
        if col in df.columns:
            df[col] = df[col].map(bool_map)
            df[col] = df[col].astype(object).where(df[col].notna(), None)

    return df

# %%
#Force mysql safe values
def df_to_mysql_safe(df: pd.DataFrame) -> pd.DataFrame:
    df = df.astype(object)
    df = df.replace({np.nan: None})
    return df

# %%
# Load CSV data
csv_path = "applications.csv"
df_csv = load_and_clean_csv(csv_path)
df_csv = df_csv[["ApplicationID","ApplicationDate","DateEmailReceived","Approved", "ApprovedDate", "SampleSent", "ResultReceived"]]
df_csv = df_to_mysql_safe(df_csv)

df_csv.head()
# Out:
#   ApplicationID ApplicationDate DateEmailReceived Approved ApprovedDate  \
# 0         P2131      2025-04-06        2025-04-06      1.0   2025-06-06
# 1         P2194      2025-01-07        2025-01-07      1.0   2025-02-07
# 2         P2033            None              None      1.0         None
# 3         P1235            None              None      1.0         None
# 4         P1998            None              None      1.0         None
#
#   SampleSent ResultReceived
# 0        1.0            1.0
# 1        1.0            1.0
# 2        1.0            1.0
# 3        1.0            1.0
# 4        1.0            1.0

# %%
# Load corresponding mysql data
def load_mysql_data(conn, application_ids):
    placeholders = ",".join(["%s"] * len(application_ids))
    sql_query = f"""
        SELECT
            ApplicationID,
            ApplicationDate,
            DateEmailReceived,
            Approved,
            ApprovedDate,
            SampleSent,
            ResultReceived
        FROM application
        WHERE ApplicationID IN ({placeholders})
    """
    return pd.read_sql(sql_query, conn, params=application_ids)

# %%
application_ids = df_csv["ApplicationID"].dropna().tolist()
df_db = load_mysql_data(conn, application_ids)
df_db = df_to_mysql_safe(df_db)

df_db.head()
# Out:
# C:\Users\PachawoBisani\AppData\Local\Temp\ipykernel_10696\1555535017.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql(sql_query, conn, params=application_ids)
#   ApplicationID ApplicationDate    DateEmailReceived Approved ApprovedDate  \
# 0         P1530      2024-05-08  2024-05-08 00:00:00        1   2024-12-08
# 1         P1205      2024-03-03  2024-08-03 00:00:00        1         None
# 2         P1205      2024-03-03  2024-08-03 00:00:00        1         None
# 3         P1187      2023-05-12  2023-06-12 00:00:00        2   2023-08-12
# 4         P1202      2023-12-15  2023-12-18 00:00:00        1   2023-12-19
#
#   SampleSent ResultReceived
# 0          1              1
# 1          1              1
# 2          1              1
# 3          2              2
# 4          1              1

# %%
#Remove duplicates
df_csv = df_csv.drop_duplicates(subset="ApplicationID", keep="first")
df_db = df_db.drop_duplicates(subset="ApplicationID", keep="first")

#ALight dataframes
df_csv = df_csv.set_index("ApplicationID").sort_index()
df_db  = df_db.set_index("ApplicationID").sort_index()


# Ensure same column order
df_db = df_db[df_csv.columns]

# %%
# Sanity check
if not df_csv.index.is_unique:
    dupes = df_csv.index[df_csv.index.duplicated()].unique()
    raise ValueError(f"Duplicate ApplicationIDs found: {list(dupes)}")

if not df_db.index.is_unique:
    dupes = df_db.index[df_db.index.duplicated()].unique()
    raise ValueError(f"Duplicate ApplicationIDs found: {list(dupes)}")

assert df_csv.index.is_unique
assert df_db.index.is_unique
assert list(df_csv.columns) == list(df_db.columns)

# %%
diff = df_csv.compare(df_db, keep_equal=False)
diff
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10696\2232174046.py in ?()
# ----> 1 diff = df_csv.compare(df_db, keep_equal=False)
#       2 diff
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, other, align_axis, keep_shape, keep_equal, result_names)
#    8589         keep_shape: bool = False,
#    8590         keep_equal: bool = False,
#    8591         result_names: Suffixes = ("self", "other"),
#    8592     ) -> DataFrame:
# -> 8593         return super().compare(
#    8594             other=other,
#    8595             align_axis=align_axis,
#    8596             keep_shape=keep_shape,
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, other, align_axis, keep_shape, keep_equal, result_names)
#   10117             raise TypeError(
#   10118                 f"can only compare '{cls_self}' (not '{cls_other}') with '{cls_self}'"
#   10119             )
#   10120
# > 10121         mask = ~((self == other) | (self.isna() & other.isna()))
#   10122         mask.fillna(True, inplace=True)
#   10123
#   10124         if not keep_equal:
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, other, op)
#    7894     def _cmp_method(self, other, op):
#    7895         axis: Literal[1] = 1  # only relevant for Series other case
#    7896
# -> 7897         self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7898
#    7899         # See GH#4537 for discussion of scalar op behavior
#    7900         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, other, axis, flex, level)
#    8192                     left, right = left.align(
#    8193                         right, join="outer", level=level, copy=False
#    8194                     )
#    8195                 else:
# -> 8196                     raise ValueError(
#    8197                         "Can only compare identically-labeled (both index and columns) "
#    8198                         "DataFrame objects"
#    8199                     )
#
# ValueError: Can only compare identically-labeled (both index and columns) DataFrame objects

# %%
def build_change_log(diff_df):
    changes = []

    for app_id in diff_df.index:
        for col in diff_df.columns.levels[0]:
            if col in diff_df.columns:
                changes.append({
                    "ApplicationID": app_id,
                    "Field": col,
                    "OldValue": diff_df.loc[app_id, (col, "other")],
                    "NewValue": diff_df.loc[app_id, (col, "self")]
                })

    return pd.DataFrame(changes)

# %%
change_log = build_change_log(diff)
change_log.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 change_log = build_change_log(diff)
#       2 change_log.head()
#
# NameError: name 'diff' is not defined
